# %%
import cv2, matplotlib
import numpy as np
import matplotlib.pyplot as plt

chips = cv2.imread('rev.png')
chips_gray = cv2.cvtColor(chips, cv2.COLOR_BGR2GRAY)
plt.imshow(chips_gray)

# %%
chips_preprocessed = cv2.GaussianBlur(chips_gray, (5, 5), 0)
plt.imshow(chips_preprocessed)

# %%
_, chips_binary = cv2.threshold(chips_preprocessed, 250, 255, cv2.THRESH_BINARY)
chips_binary = cv2.bitwise_not(chips_binary)
plt.imshow(chips_binary)
plt.axis('off')
# Out:
# (-0.5, 891.5, 650.5, -0.5)

# %%
(x,y),radius = cv2.minEnclosingCircle(chips_binary)
center = (int(x),int(y))
radius = int(radius)
img = cv2.circle(img,center,radius,(0,255,0),2)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-9-f5e8b2858e9e> in <module>
# ----> 1 (x,y),radius = cv2.minEnclosingCircle(chips_binary)
#       2 center = (int(x),int(y))
#       3 radius = int(radius)
#       4 img = cv2.circle(img,center,radius,(0,255,0),2)
#
# error: OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/shapedescr.cpp:160: error: (-215:Assertion failed) count >= 0 && (depth == CV_32F || depth == CV_32S) in function 'minEnclosingCircle'

# %%
ellipse = cv2.fitEllipse(chips_binary)
im = cv2.ellipse(im,ellipse,(0,255,0),2)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-10-b167e22d86ec> in <module>
# ----> 1 ellipse = cv2.fitEllipse(chips_binary)
#       2 im = cv2.ellipse(im,ellipse,(0,255,0),2)
#
# error: OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/shapedescr.cpp:307: error: (-215:Assertion failed) n >= 0 && (depth == CV_32F || depth == CV_32S) in function 'fitEllipse'

# %%
rows,cols = img.shape[:2]
[vx,vy,x,y] = cv2.fitLine(chips_binary, cv2.DIST_L2,0,0.01,0.01)
lefty = int((-x*vy/vx) + y)
righty = int(((cols-x)*vy/vx)+y)
img = cv2.line(img,(cols-1,righty),(0,lefty),(0,255,0),2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-9d4f3bd0c047> in <module>
# ----> 1 rows,cols = img.shape[:2]
#       2 [vx,vy,x,y] = cv2.fitLine(chips_binary, cv2.DIST_L2,0,0.01,0.01)
#       3 lefty = int((-x*vy/vx) + y)
#       4 righty = int(((cols-x)*vy/vx)+y)
#       5 img = cv2.line(img,(cols-1,righty),(0,lefty),(0,255,0),2)
#
# NameError: name 'img' is not defined
